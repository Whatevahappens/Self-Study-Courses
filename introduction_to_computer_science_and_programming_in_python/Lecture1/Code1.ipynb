# %%
import random

# %%
random.randint(16,272)
# Out:
# 201

# %%
type(3)
# Out:
# int

# %%
type(5.0)
# Out:
# float

# %%
3+2
# Out:
# 5

# %%
pi = 3.14159
radius = 2.2
area = pi*(radius**2)

# %%
print(pi)
print(radius)
print(area)
# Out:
# 3.14159
# 2.2
# 15.205295600000001
